# %%
# importing the necessary libraries
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from bs4 import BeautifulSoup

# %%
# List of url's for different parts of the website
url_dict = {
    "Men's clothing":"https://www.brownthomas.com/sale/?prefn1=refinementDivision&prefv1=MensClothing&format=page-element&start=0&sz=2000&productsearch=true",
    "Women's Clothing":"https://www.brownthomas.com/sale/?prefn1=refinementDivision&prefv1=WomensClothing&format=page-element&start=0&sz=2000&productsearch=true",
    "Eye care":"https://www.brownthomas.com/sale/?prefn1=refinementDivision&prefv1=SunglassesGlasses&format=page-element&start=0&sz=1000&productsearch=true",
    "Shoes":"https://www.brownthomas.com/sale/?prefn1=refinementDivision&prefv1=MensShoes%7CWomensShoes&format=page-element&start=0&sz=1000&productsearch=true",
    "Bags":"https://www.brownthomas.com/sale/?prefn1=refinementDivision&prefv1=WomensBags&format=page-element&start=0&sz=500&productsearch=true",
    "Technology":"https://www.brownthomas.com/sale/?prefn1=refinementDivision&prefv1=Technology&format=page-element&start=0&sz=100&productsearch=true"
}
collections = list(url_dict.keys())

# %%
# Function to extract data from an url of a particular search category
def data_extraction(category,url):
    resp=requests.get(url)
    print(resp)
    soup=BeautifulSoup(resp.content)
    ul=soup.find('div',{"class":"search-result-content js-search-result-content"})
    products = ul.find_all('li', {'class':'grid-tile js-product-grid-tile'})
    print("No of products scraped",len(products))
    info=[]
    for item in products:
        record={}
        record['brand']=item.find('span',{"class":"product-brand"}).text.replace('\n','')
        record['title'] = (item.find('span',{"class":"product-name name-link"}).text).strip('\n')
        record['salesPrice in Euro'] = (item.find('span',{"class":"product-sales-price"}).text).strip('\nNow').strip('each').strip('\A').replace('€','').replace('/',"NaN")
        record['collection'] = category
        if item.find('span',{"class":"product-standard-price"}) == None:
            record['standard_price in Euro'] = record['salesPrice in Euro'];
        else:
            record['standard_price in Euro'] = (item.find('span',{"class":"product-standard-price"}).text).strip('\nWas').strip('each').strip('\A').replace('€','').replace(',','').replace('/',"NaN")
        if item.find('span',{"class":"promo-flag"}) == None:
            record['Tag'] = "NA";
        else:
            record['Tag'] = (item.find('span',{"class":"promo-flag"}).text)
        info.append(record)
    data = pd.json_normalize(info)
    return data

# %%
# Recursively scraping the data for all categories of items from the website
scraped_data = pd.DataFrame()
for key in collections:
    scraped_data = scraped_data.append(data_extraction(key,url_dict[key]))
# Out:
# <Response [200]>
# No of products scraped 649
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\964299525.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scraped_data = scraped_data.append(data_extraction(key,url_dict[key]))
# <Response [200]>
# No of products scraped 2000
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\964299525.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scraped_data = scraped_data.append(data_extraction(key,url_dict[key]))
# <Response [200]>
# No of products scraped 190
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\964299525.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scraped_data = scraped_data.append(data_extraction(key,url_dict[key]))
# <Response [200]>
# No of products scraped 682
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\964299525.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scraped_data = scraped_data.append(data_extraction(key,url_dict[key]))
# <Response [200]>
# No of products scraped 190
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\964299525.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scraped_data = scraped_data.append(data_extraction(key,url_dict[key]))
# <Response [200]>
# No of products scraped 98
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\964299525.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   scraped_data = scraped_data.append(data_extraction(key,url_dict[key]))

# %%
scraped_data
# Out:
#           brand                                      title salesPrice in Euro  \
# 0   THE KOOPLES    Long-Sleeve Single-Breasted Suit Jacket             316.00
# 1   THE KOOPLES                     Logo Crew Neck T-Shirt              59.50
# 2   THE KOOPLES               High-Rise Wool Suit Trousers             156.00
# 3     TED BAKER        Hasting Long Sleeve Twill Overshirt              91.00
# 4     TED BAKER            Regular Printed Graphic T-Shirt              41.00
# ..          ...                                        ...                ...
# 93      TP-LINK          Tapo Outdoor Securtiy WiFi Camera              59.95
# 94      TP-LINK               Deco Whole-Home Wi-Fi 3 Pack             189.95
# 95     OTTERBOX                    Lightning Cable 1 metre              19.95
# 96     SO SEVEN                   Jaipur Leopard iPhone 11              18.99
# 97         KYGO  X by Kygo E7/1000 True Wireless Earphones              99.95
#
#         collection standard_price in Euro                        Tag
# 0   Men's clothing                 395.00  EXTRA 10% OFF AT CHECKOUT
# 1   Men's clothing                  85.00  EXTRA 10% OFF AT CHECKOUT
# 2   Men's clothing                 195.00  EXTRA 10% OFF AT CHECKOUT
# 3   Men's clothing                 130.00  EXTRA 10% OFF AT CHECKOUT
# 4   Men's clothing                  59.00  EXTRA 10% OFF AT CHECKOUT
# ..             ...                    ...                        ...
# 93      Technology                  79.95                       SALE
# 94      Technology                 189.95                       SALE
# 95      Technology                  24.95                       SALE
# 96      Technology                  39.99                       SALE
# 97      Technology                 149.95                       SALE
#
# [3809 rows x 6 columns]

# %%
'''This function is defined for Feature Engineering the customized discount feature which is unavailable on the website 
and also handles the products having a price range in euros ''' 


def feature_discounts(data):
    if (scraped_data['standard_price in Euro'].str.rsplit(' - ',1,expand=True)).shape[1] == 2:
        data[['Start Standard Price', 'End Standard Price']] = data['standard_price in Euro'].str.rsplit(' - ',1,expand=True)
    elif (scraped_data['standard_price in Euro'].str.rsplit(' - ',1,expand=True)).shape[1] == 1:
        data['Start Standard Price'] = data['standard_price in Euro'].str.rsplit(' - ',1,expand=True)
        data['End Standard Price'] = np.nan
    data['Start Standard Price'] = pd.to_numeric(data['Start Standard Price'], errors='coerce')
    data['End Standard Price'] = pd.to_numeric(data['End Standard Price'], errors='coerce')

    data[['Start Sales Price', 'End Sales Price']] = data['salesPrice in Euro'].str.split(' - ', expand=True)
    data['Start Sales Price'] = pd.to_numeric(data['Start Sales Price'], errors='coerce')
    data['End Sales Price'] = pd.to_numeric(data['End Sales Price'], errors='coerce')

    data['End Standard Price'] = data['End Standard Price'].fillna(0)
    data['Start Standard Price'] = data['Start Standard Price'].fillna(0)
    data['Standard Price(€)'] = (data['Start Standard Price'] + data['End Standard Price'])

    data['End Sales Price'] = data['End Sales Price'].fillna(0)
    data['Start Sales Price'] = data['Start Sales Price'].fillna(0)
    data['Sales Price(€)'] = (data['Start Sales Price']+data['End Sales Price'])
    
    data['Discount (%)'] = 100 - (data['Sales Price(€)']/data['Standard Price(€)'])*100
    data['Discount (%)'] = data['Discount (%)'].round(2)

    data=data.replace('/',np.nan)
    data=data[~data[['Standard Price(€)','Sales Price(€)']].isnull().all(axis=1)]
    
    return data

final_data = feature_discounts(scraped_data)
final_data
# Out:
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\4067214068.py:6: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   if (scraped_data['standard_price in Euro'].str.rsplit(' - ',1,expand=True)).shape[1] == 2:
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\4067214068.py:7: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   data[['Start Standard Price', 'End Standard Price']] = data['standard_price in Euro'].str.rsplit(' - ',1,expand=True)
#           brand                                      title salesPrice in Euro  \
# 0   THE KOOPLES    Long-Sleeve Single-Breasted Suit Jacket             316.00
# 1   THE KOOPLES                     Logo Crew Neck T-Shirt              59.50
# 2   THE KOOPLES               High-Rise Wool Suit Trousers             156.00
# 3     TED BAKER        Hasting Long Sleeve Twill Overshirt              91.00
# 4     TED BAKER            Regular Printed Graphic T-Shirt              41.00
# ..          ...                                        ...                ...
# 93      TP-LINK          Tapo Outdoor Securtiy WiFi Camera              59.95
# 94      TP-LINK               Deco Whole-Home Wi-Fi 3 Pack             189.95
# 95     OTTERBOX                    Lightning Cable 1 metre              19.95
# 96     SO SEVEN                   Jaipur Leopard iPhone 11              18.99
# 97         KYGO  X by Kygo E7/1000 True Wireless Earphones              99.95
#
#         collection standard_price in Euro                        Tag  \
# 0   Men's clothing                 395.00  EXTRA 10% OFF AT CHECKOUT
# 1   Men's clothing                  85.00  EXTRA 10% OFF AT CHECKOUT
# 2   Men's clothing                 195.00  EXTRA 10% OFF AT CHECKOUT
# 3   Men's clothing                 130.00  EXTRA 10% OFF AT CHECKOUT
# 4   Men's clothing                  59.00  EXTRA 10% OFF AT CHECKOUT
# ..             ...                    ...                        ...
# 93      Technology                  79.95                       SALE
# 94      Technology                 189.95                       SALE
# 95      Technology                  24.95                       SALE
# 96      Technology                  39.99                       SALE
# 97      Technology                 149.95                       SALE
#
#     Start Standard Price  End Standard Price  Start Sales Price  \
# 0                 395.00                 0.0             316.00
# 1                  85.00                 0.0              59.50
# 2                 195.00                 0.0             156.00
# 3                 130.00                 0.0              91.00
# 4                  59.00                 0.0              41.00
# ..                   ...                 ...                ...
# 93                 79.95                 0.0              59.95
# 94                189.95                 0.0             189.95
# 95                 24.95                 0.0              19.95
# 96                 39.99                 0.0              18.99
# 97                149.95                 0.0              99.95
#
#     End Sales Price  Standard Price(€)  Sales Price(€)  Discount (%)
# 0               0.0             395.00          316.00         20.00
# 1               0.0              85.00           59.50         30.00
# 2               0.0             195.00          156.00         20.00
# 3               0.0             130.00           91.00         30.00
# 4               0.0              59.00           41.00         30.51
# ..              ...                ...             ...           ...
# 93              0.0              79.95           59.95         25.02
# 94              0.0             189.95          189.95          0.00
# 95              0.0              24.95           19.95         20.04
# 96              0.0              39.99           18.99         52.51
# 97              0.0             149.95           99.95         33.34
#
# [3809 rows x 13 columns]

# %%
# handling the products where the price is not available and dropping them
final_data.drop(final_data[final_data['Standard Price(€)'] == 0].index, inplace=True)
final_data.drop(final_data[final_data['Sales Price(€)'] == 0].index, inplace=True)
final_data.drop(final_data[final_data['Sales Price(€)'] >  final_data['Standard Price(€)']].index, inplace=True)

# %%
# final dataframe with intermediate features
final_data
# Out:
#           brand                                      title salesPrice in Euro  \
# 0   THE KOOPLES    Long-Sleeve Single-Breasted Suit Jacket             316.00
# 1   THE KOOPLES                     Logo Crew Neck T-Shirt              59.50
# 2   THE KOOPLES               High-Rise Wool Suit Trousers             156.00
# 3     TED BAKER        Hasting Long Sleeve Twill Overshirt              91.00
# 7   THE KOOPLES                 Classic Wool Suit Trousers             122.50
# ..          ...                                        ...                ...
# 93      TP-LINK          Tapo Outdoor Securtiy WiFi Camera              59.95
# 94      TP-LINK               Deco Whole-Home Wi-Fi 3 Pack             189.95
# 95     OTTERBOX                    Lightning Cable 1 metre              19.95
# 96     SO SEVEN                   Jaipur Leopard iPhone 11              18.99
# 97         KYGO  X by Kygo E7/1000 True Wireless Earphones              99.95
#
#         collection standard_price in Euro                        Tag  \
# 0   Men's clothing                 395.00  EXTRA 10% OFF AT CHECKOUT
# 1   Men's clothing                  85.00  EXTRA 10% OFF AT CHECKOUT
# 2   Men's clothing                 195.00  EXTRA 10% OFF AT CHECKOUT
# 3   Men's clothing                 130.00  EXTRA 10% OFF AT CHECKOUT
# 7   Men's clothing                 245.00  EXTRA 10% OFF AT CHECKOUT
# ..             ...                    ...                        ...
# 93      Technology                  79.95                       SALE
# 94      Technology                 189.95                       SALE
# 95      Technology                  24.95                       SALE
# 96      Technology                  39.99                       SALE
# 97      Technology                 149.95                       SALE
#
#     Start Standard Price  End Standard Price  Start Sales Price  \
# 0                 395.00                 0.0             316.00
# 1                  85.00                 0.0              59.50
# 2                 195.00                 0.0             156.00
# 3                 130.00                 0.0              91.00
# 7                 245.00                 0.0             122.50
# ..                   ...                 ...                ...
# 93                 79.95                 0.0              59.95
# 94                189.95                 0.0             189.95
# 95                 24.95                 0.0              19.95
# 96                 39.99                 0.0              18.99
# 97                149.95                 0.0              99.95
#
#     End Sales Price  Standard Price(€)  Sales Price(€)  Discount (%)
# 0               0.0             395.00          316.00         20.00
# 1               0.0              85.00           59.50         30.00
# 2               0.0             195.00          156.00         20.00
# 3               0.0             130.00           91.00         30.00
# 7               0.0             245.00          122.50         50.00
# ..              ...                ...             ...           ...
# 93              0.0              79.95           59.95         25.02
# 94              0.0             189.95          189.95          0.00
# 95              0.0              24.95           19.95         20.04
# 96              0.0              39.99           18.99         52.51
# 97              0.0             149.95           99.95         33.34
#
# [3703 rows x 13 columns]

# %%
# feature engineering for getting the type of product from the title text
final_data[['info', 'Product Type']] = final_data['title'].str.rsplit(' ',1,expand=True)
final_data.to_csv("scraped-data.csv", index = False)
# Out:
# C:\Users\sonal\AppData\Local\Temp\ipykernel_30928\3118844978.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.rsplit except for the argument 'pat' will be keyword-only.
#   final_data[['info', 'Product Type']] = final_data['title'].str.rsplit(' ',1,expand=True)

# %%
# dropping the intermediate features
final_data = final_data.drop(['salesPrice in Euro','standard_price in Euro','Start Sales Price','End Sales Price','Start Standard Price','End Standard Price'], axis =1)

# %%
final_data
# Out:
#           brand                                      title      collection  \
# 0   THE KOOPLES    Long-Sleeve Single-Breasted Suit Jacket  Men's clothing
# 1   THE KOOPLES                     Logo Crew Neck T-Shirt  Men's clothing
# 2   THE KOOPLES               High-Rise Wool Suit Trousers  Men's clothing
# 3     TED BAKER        Hasting Long Sleeve Twill Overshirt  Men's clothing
# 7   THE KOOPLES                 Classic Wool Suit Trousers  Men's clothing
# ..          ...                                        ...             ...
# 93      TP-LINK          Tapo Outdoor Securtiy WiFi Camera      Technology
# 94      TP-LINK               Deco Whole-Home Wi-Fi 3 Pack      Technology
# 95     OTTERBOX                    Lightning Cable 1 metre      Technology
# 96     SO SEVEN                   Jaipur Leopard iPhone 11      Technology
# 97         KYGO  X by Kygo E7/1000 True Wireless Earphones      Technology
#
#                           Tag  Standard Price(€)  Sales Price(€)  \
# 0   EXTRA 10% OFF AT CHECKOUT             395.00          316.00
# 1   EXTRA 10% OFF AT CHECKOUT              85.00           59.50
# 2   EXTRA 10% OFF AT CHECKOUT             195.00          156.00
# 3   EXTRA 10% OFF AT CHECKOUT             130.00           91.00
# 7   EXTRA 10% OFF AT CHECKOUT             245.00          122.50
# ..                        ...                ...             ...
# 93                       SALE              79.95           59.95
# 94                       SALE             189.95          189.95
# 95                       SALE              24.95           19.95
# 96                       SALE              39.99           18.99
# 97                       SALE             149.95           99.95
#
#     Discount (%)                              info Product Type
# 0          20.00  Long-Sleeve Single-Breasted Suit       Jacket
# 1          30.00                    Logo Crew Neck      T-Shirt
# 2          20.00               High-Rise Wool Suit     Trousers
# 3          30.00         Hasting Long Sleeve Twill    Overshirt
# 7          50.00                 Classic Wool Suit     Trousers
# ..           ...                               ...          ...
# 93         25.02        Tapo Outdoor Securtiy WiFi       Camera
# 94          0.00           Deco Whole-Home Wi-Fi 3         Pack
# 95         20.04                 Lightning Cable 1        metre
# 96         52.51             Jaipur Leopard iPhone           11
# 97         33.34   X by Kygo E7/1000 True Wireless    Earphones
#
# [3703 rows x 9 columns]

# %%
# Installing the mongo db driver
#!python -m pip install pymongo[srv]

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi


uri = "mongodb+srv://akashlhire:pipeline@database1.k8sd2do.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
data = final_data.to_dict(orient = "records")

# %%
# Handling the existing data for deduplication

db = client["Brown_Thomas_Scrapper"]
list_of_collections = db.list_collection_names()
if 'Products' not in list_of_collections:
    db.create_collection('Products')
else:
    col = db['Products']
    col.delete_many({})

# %%
# Pushing the data to mongodb
db.Products.insert_many(data)

# %%
print(db.list_collection_names())
# Out:
# ['Products']

# %%
db.Products.count_documents({})
# Out:
# 3703

# %%
record = db['Products'].find()
for doc in record:
    if '_id' in doc:
        del doc['_id']
        print(doc)
# Out:
# {'brand': 'THE KOOPLES', 'title': 'Long-Sleeve Single-Breasted Suit Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 395.0, 'Sales Price(€)': 316.0, 'Discount (%)': 20.0, 'info': 'Long-Sleeve Single-Breasted Suit', 'Product Type': 'Jacket'}
# {'brand': 'THE KOOPLES', 'title': 'Logo Crew Neck T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 59.5, 'Discount (%)': 30.0, 'info': 'Logo Crew Neck', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'High-Rise Wool Suit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 156.0, 'Discount (%)': 20.0, 'info': 'High-Rise Wool Suit', 'Product Type': 'Trousers'}
# {'brand': 'TED BAKER', 'title': 'Hasting Long Sleeve Twill Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 91.0, 'Discount (%)': 30.0, 'info': 'Hasting Long Sleeve Twill', 'Product Type': 'Overshirt'}
# {'brand': 'THE KOOPLES', 'title': 'Classic Wool Suit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 245.0, 'Sales Price(€)': 122.5, 'Discount (%)': 50.0, 'info': 'Classic Wool Suit', 'Product Type': 'Trousers'}
# {'brand': 'REISS', 'title': 'Searcy Linen Shorts', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 92.0, 'Discount (%)': 34.29, 'info': 'Searcy Linen', 'Product Type': 'Shorts'}
# {'brand': 'REISS', 'title': 'Hendrix Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 62.0, 'Discount (%)': 34.74, 'info': 'Hendrix Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Leo Wool Zip Neck Polo', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 64.0, 'Discount (%)': 62.35, 'info': 'Leo Wool Zip Neck', 'Product Type': 'Polo'}
# {'brand': 'REISS', 'title': 'Kace Garment Dye Hoodie', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 64.0, 'Discount (%)': 54.29, 'info': 'Kace Garment Dye', 'Product Type': 'Hoodie'}
# {'brand': 'TED BAKER', 'title': 'Belmar Botanical Print Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 115.0, 'Sales Price(€)': 80.0, 'Discount (%)': 30.43, 'info': 'Belmar Botanical Print', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Caplet Oxford Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 99.0, 'Sales Price(€)': 49.0, 'Discount (%)': 50.51, 'info': 'Caplet Oxford', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Sampson Cuban Collar Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 93.0, 'Discount (%)': 45.29, 'info': 'Sampson Cuban Collar', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Wade Slim Leg Jeans', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 57.0, 'Discount (%)': 59.29, 'info': 'Wade Slim Leg', 'Product Type': 'Jeans'}
# {'brand': 'TED BAKER', 'title': 'Haworth Knitted Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 100.0, 'Sales Price(€)': 50.0, 'Discount (%)': 50.0, 'info': 'Haworth Knitted Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Carlby Wool Coat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 425.0, 'Sales Price(€)': 170.0, 'Discount (%)': 60.0, 'info': 'Carlby Wool', 'Product Type': 'Coat'}
# {'brand': 'REISS', 'title': 'Roddie Long Sleeve Quilted Hybrid Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 245.0, 'Sales Price(€)': 130.0, 'Discount (%)': 46.94, 'info': 'Roddie Long Sleeve Quilted Hybrid', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Caspa Mercerised Cuban Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 58.0, 'Discount (%)': 38.95, 'info': 'Caspa Mercerised Cuban', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Creswel Elasticated Drawstring Shorts', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 100.0, 'Sales Price(€)': 70.0, 'Discount (%)': 30.0, 'info': 'Creswel Elasticated Drawstring', 'Product Type': 'Shorts'}
# {'brand': 'REISS', 'title': 'Roddie Long Sleeve Quilted Hybrid Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 245.0, 'Sales Price(€)': 103.0, 'Discount (%)': 57.96, 'info': 'Roddie Long Sleeve Quilted Hybrid', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Kid Half Zip Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 64.0, 'Discount (%)': 54.29, 'info': 'Kid Half Zip Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Vienna Wool Button Through Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 395.0, 'Sales Price(€)': 134.0, 'Discount (%)': 66.08, 'info': 'Vienna Wool Button Through', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Fival Textured Harrington Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 325.0, 'Sales Price(€)': 135.0, 'Discount (%)': 58.46, 'info': 'Fival Textured Harrington', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Holmes Ribbed Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 64.0, 'Discount (%)': 62.35, 'info': 'Holmes Ribbed Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Stall Seersucker Relaxed Fit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 63.0, 'Discount (%)': 67.69, 'info': 'Stall Seersucker Relaxed Fit', 'Product Type': 'Trousers'}
# {'brand': 'TED BAKER', 'title': 'Tinot Abstract Watercolour Print T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 59.0, 'Sales Price(€)': 35.0, 'Discount (%)': 40.68, 'info': 'Tinot Abstract Watercolour Print', 'Product Type': 'T-Shirt'}
# {'brand': 'REISS', 'title': 'Duchie Merino Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 85.0, 'Discount (%)': 10.53, 'info': 'Duchie Merino Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Wool Collared Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 295.0, 'Sales Price(€)': 147.0, 'Discount (%)': 50.17, 'info': 'Wool Collared', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Miami Long Sleeve Twin Pocket Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 86.0, 'Sales Price(€)': 86.0, 'Discount (%)': 0.0, 'info': 'Miami Long Sleeve Twin Pocket', 'Product Type': 'Overshirt'}
# {'brand': 'TED BAKER', 'title': 'Bellow Long Sleeve Satin Stretch Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 115.0, 'Sales Price(€)': 57.0, 'Discount (%)': 50.43, 'info': 'Bellow Long Sleeve Satin Stretch', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Herald Striped Half Zip Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 145.0, 'Sales Price(€)': 67.0, 'Discount (%)': 53.79, 'info': 'Herald Striped Half Zip Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Allard Jacquard Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 59.0, 'Discount (%)': 30.59, 'info': 'Allard Jacquard Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Angelo Check Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 105.0, 'Discount (%)': 46.15, 'info': 'Angelo Check', 'Product Type': 'Overshirt'}
# {'brand': 'TED BAKER', 'title': 'Kymsho Floral Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 110.0, 'Sales Price(€)': 77.0, 'Discount (%)': 30.0, 'info': 'Kymsho Floral', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Bering Mixed Stripe Rugby Polo', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 50.0, 'Discount (%)': 60.0, 'info': 'Bering Mixed Stripe Rugby', 'Product Type': 'Polo'}
# {'brand': 'TED BAKER', 'title': 'Kilbrn Half Zip Sweatshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 115.0, 'Sales Price(€)': 57.0, 'Discount (%)': 50.43, 'info': 'Kilbrn Half Zip', 'Product Type': 'Sweatshirt'}
# {'brand': 'TED BAKER', 'title': 'Capsho Short Sleeve Oxford Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 100.0, 'Sales Price(€)': 70.0, 'Discount (%)': 30.0, 'info': 'Capsho Short Sleeve Oxford', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Bergamo Wool Blend Herringbone Peacoat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 425.0, 'Sales Price(€)': 256.0, 'Discount (%)': 39.76, 'info': 'Bergamo Wool Blend Herringbone', 'Product Type': 'Peacoat'}
# {'brand': 'REISS', 'title': 'Pike Suede Zip-Through Trucker Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 540.0, 'Sales Price(€)': 257.0, 'Discount (%)': 52.41, 'info': 'Pike Suede Zip-Through Trucker', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Holiday Linen Slim Fit Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 120.0, 'Sales Price(€)': 77.0, 'Discount (%)': 35.83, 'info': 'Holiday Linen Slim Fit', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'East Long Sleeve Press Stud Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 70.0, 'Discount (%)': 64.1, 'info': 'East Long Sleeve Press Stud Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Jack Jacquard Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 64.0, 'Discount (%)': 54.29, 'info': 'Jack Jacquard', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Herald Striped Half Zip Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 145.0, 'Sales Price(€)': 67.0, 'Discount (%)': 53.79, 'info': 'Herald Striped Half Zip Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Frost Faux Fur Trim Puffer Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 425.0, 'Sales Price(€)': 135.0, 'Discount (%)': 68.24, 'info': 'Frost Faux Fur Trim Puffer', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Taigaa Stripe Panelled Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 42.0, 'Discount (%)': 50.59, 'info': 'Taigaa Stripe Panelled Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Ricco Open Collar Stripe Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 108.0, 'Discount (%)': 36.47, 'info': 'Ricco Open Collar Stripe Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Baren Irvine Fit Textured Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 87.0, 'Discount (%)': 30.4, 'info': 'Baren Irvine Fit Textured', 'Product Type': 'Trousers'}
# {'brand': 'REISS', 'title': 'Hendrix Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 62.0, 'Discount (%)': 34.74, 'info': 'Hendrix Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Bear Micro Fleece Joggers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 64.0, 'Discount (%)': 62.35, 'info': 'Bear Micro Fleece', 'Product Type': 'Joggers'}
# {'brand': 'REISS', 'title': 'Dudley Half-Zip Tipped Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 145.0, 'Sales Price(€)': 80.0, 'Discount (%)': 44.83, 'info': 'Dudley Half-Zip Tipped Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Spark Single-Breasted Blazer', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 425.0, 'Sales Price(€)': 320.0, 'Discount (%)': 24.71, 'info': 'Spark Single-Breasted', 'Product Type': 'Blazer'}
# {'brand': 'TED BAKER', 'title': 'Quarts Straight Leg Chinos', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 65.0, 'Discount (%)': 50.0, 'info': 'Quarts Straight Leg', 'Product Type': 'Chinos'}
# {'brand': 'TED BAKER', 'title': 'Fonik Long Sleeve Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 99.0, 'Sales Price(€)': 49.0, 'Discount (%)': 50.51, 'info': 'Fonik Long Sleeve', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Tooting Half Zip Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 65.0, 'Discount (%)': 50.0, 'info': 'Tooting Half Zip', 'Product Type': 'Sweater'}
# {'brand': 'REISS', 'title': 'Holland Merino Wool Hoodie', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 92.0, 'Discount (%)': 34.29, 'info': 'Holland Merino Wool', 'Product Type': 'Hoodie'}
# {'brand': 'THE KOOPLES', 'title': 'Leopard Logo Sweatshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 97.5, 'Discount (%)': 50.0, 'info': 'Leopard Logo', 'Product Type': 'Sweatshirt'}
# {'brand': 'REISS', 'title': 'Dale Slim Fit Wool Blazer', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 240.0, 'Sales Price(€)': 107.0, 'Discount (%)': 55.42, 'info': 'Dale Slim Fit Wool', 'Product Type': 'Blazer'}
# {'brand': 'REISS', 'title': 'Ancroft Prince Of Wales Check Blazer', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 395.0, 'Sales Price(€)': 212.0, 'Discount (%)': 46.33, 'info': 'Ancroft Prince Of Wales Check', 'Product Type': 'Blazer'}
# {'brand': 'THE KOOPLES', 'title': 'Zig-Zag Jacquard Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 175.0, 'Sales Price(€)': 87.5, 'Discount (%)': 50.0, 'info': 'Zig-Zag Jacquard', 'Product Type': 'Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Snake Print Jacquard Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 185.0, 'Sales Price(€)': 92.5, 'Discount (%)': 50.0, 'info': 'Snake Print Jacquard', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Talacre Reversible Wadded Coach Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 230.0, 'Sales Price(€)': 92.0, 'Discount (%)': 60.0, 'info': 'Talacre Reversible Wadded Coach', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Kilbrn Half Zip Sweatshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 115.0, 'Sales Price(€)': 57.0, 'Discount (%)': 50.43, 'info': 'Kilbrn Half Zip', 'Product Type': 'Sweatshirt'}
# {'brand': 'REISS', 'title': 'Frost Faux Fur Trim Puffer Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 425.0, 'Sales Price(€)': 228.0, 'Discount (%)': 46.35, 'info': 'Frost Faux Fur Trim Puffer', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Paplet Long Sleeve Oxford Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 99.0, 'Sales Price(€)': 50.0, 'Discount (%)': 49.49, 'info': 'Paplet Long Sleeve Oxford', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Taigaa Stripe Panelled Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 42.0, 'Discount (%)': 50.59, 'info': 'Taigaa Stripe Panelled Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Gable Epsom Overcoat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 420.0, 'Sales Price(€)': 242.0, 'Discount (%)': 42.38, 'info': 'Gable Epsom', 'Product Type': 'Overcoat'}
# {'brand': 'THE KOOPLES', 'title': 'Slim Leg Jeans', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 155.0, 'Sales Price(€)': 77.5, 'Discount (%)': 50.0, 'info': 'Slim Leg', 'Product Type': 'Jeans'}
# {'brand': 'TED BAKER', 'title': 'Creswel Elasticated Drawstring Shorts', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 100.0, 'Sales Price(€)': 70.0, 'Discount (%)': 30.0, 'info': 'Creswel Elasticated Drawstring', 'Product Type': 'Shorts'}
# {'brand': 'TED BAKER', 'title': 'Coram Jacquard Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 100.0, 'Sales Price(€)': 50.0, 'Discount (%)': 50.0, 'info': 'Coram Jacquard Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Tokyo Colour block Open Collar Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 78.0, 'Discount (%)': 44.29, 'info': 'Tokyo Colour block Open Collar', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Bonucci Corduroy Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 93.0, 'Discount (%)': 45.29, 'info': 'Bonucci Corduroy', 'Product Type': 'Overshirt'}
# {'brand': 'TED BAKER', 'title': 'Fonik Long Sleeve Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 99.0, 'Sales Price(€)': 49.0, 'Discount (%)': 50.51, 'info': 'Fonik Long Sleeve', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Wessex Crew Neck Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 78.0, 'Discount (%)': 37.6, 'info': 'Wessex Crew Neck', 'Product Type': 'Sweater'}
# {'brand': 'TED BAKER', 'title': 'Kenton V-Neck Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 110.0, 'Sales Price(€)': 55.0, 'Discount (%)': 50.0, 'info': 'Kenton V-Neck', 'Product Type': 'Sweater'}
# {'brand': 'TED BAKER', 'title': 'Allard Jacquard Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 59.0, 'Discount (%)': 30.59, 'info': 'Allard Jacquard Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Titan Check Woven Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 245.0, 'Sales Price(€)': 82.0, 'Discount (%)': 66.53, 'info': 'Titan Check Woven', 'Product Type': 'Overshirt'}
# {'brand': 'TED BAKER', 'title': 'Witree Long Sleeve Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 65.0, 'Discount (%)': 50.0, 'info': 'Witree Long Sleeve', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Bushey Botanical Border Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 165.0, 'Sales Price(€)': 115.0, 'Discount (%)': 30.3, 'info': 'Bushey Botanical Border', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Pearsho Short Sleeve Geometric Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 110.0, 'Sales Price(€)': 77.0, 'Discount (%)': 30.0, 'info': 'Pearsho Short Sleeve Geometric', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Alistar Garment Dye Sweatshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 54.0, 'Discount (%)': 43.16, 'info': 'Alistar Garment Dye', 'Product Type': 'Sweatshirt'}
# {'brand': 'REISS', 'title': 'Quinn Contrast Trim Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 135.0, 'Sales Price(€)': 63.0, 'Discount (%)': 53.33, 'info': 'Quinn Contrast Trim Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Camdun Slim Leg Denim Jeans', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 75.0, 'Discount (%)': 40.0, 'info': 'Camdun Slim Leg Denim', 'Product Type': 'Jeans'}
# {'brand': 'THE KOOPLES', 'title': 'Logo Print T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 80.0, 'Sales Price(€)': 40.0, 'Discount (%)': 50.0, 'info': 'Logo Print', 'Product Type': 'T-Shirt'}
# {'brand': 'TED BAKER', 'title': 'Bossa Monogram Pocket T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 80.0, 'Sales Price(€)': 40.0, 'Discount (%)': 50.0, 'info': 'Bossa Monogram Pocket', 'Product Type': 'T-Shirt'}
# {'brand': 'REISS', 'title': 'Marley Brushed Check Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 185.0, 'Sales Price(€)': 72.0, 'Discount (%)': 61.08, 'info': 'Marley Brushed Check', 'Product Type': 'Overshirt'}
# {'brand': 'TED BAKER', 'title': 'Soft Touch Long Sleeve Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 110.0, 'Sales Price(€)': 77.0, 'Discount (%)': 30.0, 'info': 'Soft Touch Long Sleeve Polo', 'Product Type': 'Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Zip-Through Leather Bomber Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 595.0, 'Sales Price(€)': 297.5, 'Discount (%)': 50.0, 'info': 'Zip-Through Leather Bomber', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Lemar Technical Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 93.0, 'Discount (%)': 45.29, 'info': 'Lemar Technical', 'Product Type': 'Trousers'}
# {'brand': 'REISS', 'title': 'Ryder Puffer Coat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 425.0, 'Sales Price(€)': 199.0, 'Discount (%)': 53.18, 'info': 'Ryder Puffer', 'Product Type': 'Coat'}
# {'brand': 'REISS', 'title': 'Baron Mercerised Jersey Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 54.0, 'Discount (%)': 43.16, 'info': 'Baron Mercerised Jersey', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Keanuj Slim Fit Jersey Blazer', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 360.0, 'Sales Price(€)': 231.0, 'Discount (%)': 35.83, 'info': 'Keanuj Slim Fit Jersey', 'Product Type': 'Blazer'}
# {'brand': 'THE KOOPLES', 'title': 'Logo Patch Crew Neck T Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 42.5, 'Discount (%)': 50.0, 'info': 'Logo Patch Crew Neck T', 'Product Type': 'Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Skull Screenprint T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 47.5, 'Discount (%)': 50.0, 'info': 'Skull Screenprint', 'Product Type': 'T-Shirt'}
# {'brand': 'REISS', 'title': 'Cast Brushed Dogtooth Overcoat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 525.0, 'Sales Price(€)': 242.0, 'Discount (%)': 53.9, 'info': 'Cast Brushed Dogtooth', 'Product Type': 'Overcoat'}
# {'brand': 'REISS', 'title': 'Bark Epsom Wool Blend Check Overcoat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 525.0, 'Sales Price(€)': 192.0, 'Discount (%)': 63.43, 'info': 'Bark Epsom Wool Blend Check', 'Product Type': 'Overcoat'}
# {'brand': 'REISS', 'title': 'Pitch Washed Slim Fit Chinos', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 54.0, 'Discount (%)': 43.16, 'info': 'Pitch Washed Slim Fit', 'Product Type': 'Chinos'}
# {'brand': 'THE KOOPLES', 'title': 'Slim Leg Jeans', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 155.0, 'Sales Price(€)': 77.5, 'Discount (%)': 50.0, 'info': 'Slim Leg', 'Product Type': 'Jeans'}
# {'brand': 'TED BAKER', 'title': 'Cambly Slim Leg Denim Jeans', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 75.0, 'Discount (%)': 40.0, 'info': 'Cambly Slim Leg Denim', 'Product Type': 'Jeans'}
# {'brand': 'TED BAKER', 'title': 'Mangata Abstract Print T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 59.0, 'Sales Price(€)': 41.0, 'Discount (%)': 30.51, 'info': 'Mangata Abstract Print', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'The Kooples Screen Print Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 215.0, 'Sales Price(€)': 107.5, 'Discount (%)': 50.0, 'info': 'The Kooples Screen Print', 'Product Type': 'Sweater'}
# {'brand': 'REISS', 'title': 'Kiss Casentino Twin Pocket Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 65.0, 'Discount (%)': 66.67, 'info': 'Kiss Casentino Twin Pocket', 'Product Type': 'Overshirt'}
# {'brand': 'TED BAKER', 'title': 'Shakerj Slim Fit Cotton Linen Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 385.0, 'Sales Price(€)': 177.0, 'Discount (%)': 54.03, 'info': 'Shakerj Slim Fit Cotton Linen', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Wragby Tonal Magnolia Jacquard Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 65.0, 'Discount (%)': 50.0, 'info': 'Wragby Tonal Magnolia Jacquard', 'Product Type': 'Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Leopard Screenprint T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 62.5, 'Discount (%)': 50.0, 'info': 'Leopard Screenprint', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Wool Tailored Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 235.0, 'Sales Price(€)': 117.5, 'Discount (%)': 50.0, 'info': 'Wool Tailored', 'Product Type': 'Trousers'}
# {'brand': 'TED BAKER', 'title': 'Portmay Dogtooth Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 87.0, 'Discount (%)': 30.4, 'info': 'Portmay Dogtooth', 'Product Type': 'Trousers'}
# {'brand': 'THE KOOPLES', 'title': 'Marble Print Zip-Through Sweatshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 295.0, 'Sales Price(€)': 147.5, 'Discount (%)': 50.0, 'info': 'Marble Print Zip-Through', 'Product Type': 'Sweatshirt'}
# {'brand': 'REISS', 'title': 'Sinclair Quilted Hybrid Funnel Neck Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 285.0, 'Sales Price(€)': 107.0, 'Discount (%)': 62.46, 'info': 'Sinclair Quilted Hybrid Funnel Neck', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Baren Irvine Fit Textured Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 87.0, 'Discount (%)': 30.4, 'info': 'Baren Irvine Fit Textured', 'Product Type': 'Trousers'}
# {'brand': 'REISS', 'title': 'Wessex Crew Neck Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 85.0, 'Discount (%)': 32.0, 'info': 'Wessex Crew Neck', 'Product Type': 'Sweater'}
# {'brand': 'TED BAKER', 'title': 'Duddin Henley T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 70.0, 'Sales Price(€)': 49.0, 'Discount (%)': 30.0, 'info': 'Duddin Henley', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Rib Knit Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 245.0, 'Sales Price(€)': 122.5, 'Discount (%)': 50.0, 'info': 'Rib Knit', 'Product Type': 'Sweater'}
# {'brand': 'TED BAKER', 'title': 'Raydon Single Breasted Wool Coat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 425.0, 'Sales Price(€)': 255.0, 'Discount (%)': 40.0, 'info': 'Raydon Single Breasted Wool', 'Product Type': 'Coat'}
# {'brand': 'REISS', 'title': 'Bonucci Corduroy Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 64.0, 'Discount (%)': 62.35, 'info': 'Bonucci Corduroy', 'Product Type': 'Overshirt'}
# {'brand': 'REISS', 'title': 'James Long Sleeve Textured Over Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 71.0, 'Discount (%)': 49.29, 'info': 'James Long Sleeve Textured Over', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Paplet Long Sleeve Oxford Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 99.0, 'Sales Price(€)': 50.0, 'Discount (%)': 49.49, 'info': 'Paplet Long Sleeve Oxford', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Vadell Striped T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 70.0, 'Sales Price(€)': 35.0, 'Discount (%)': 50.0, 'info': 'Vadell Striped', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Single-Breasted Wool Suit Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 445.0, 'Sales Price(€)': 222.5, 'Discount (%)': 50.0, 'info': 'Single-Breasted Wool Suit', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Long-Sleeve Circle Weave Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 47.0, 'Discount (%)': 50.53, 'info': 'Long-Sleeve Circle Weave', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Harry Checked Twin Pocket Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 57.0, 'Discount (%)': 66.47, 'info': 'Harry Checked Twin Pocket', 'Product Type': 'Overshirt'}
# {'brand': 'THE KOOPLES', 'title': 'Love Kooples Logo Hoodie', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 97.5, 'Discount (%)': 50.0, 'info': 'Love Kooples Logo', 'Product Type': 'Hoodie'}
# {'brand': 'REISS', 'title': 'Plaza Hybrid Funnel Neck Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 77.0, 'Discount (%)': 60.51, 'info': 'Plaza Hybrid Funnel Neck', 'Product Type': 'Sweater'}
# {'brand': 'TED BAKER', 'title': 'Chapar Branded Print Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 51.0, 'Discount (%)': 40.0, 'info': 'Chapar Branded Print Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Vennel Floral Print T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 59.0, 'Sales Price(€)': 41.0, 'Discount (%)': 30.51, 'info': 'Vennel Floral Print', 'Product Type': 'T-Shirt'}
# {'brand': 'REISS', 'title': 'Miami Twin Pocket Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 185.0, 'Sales Price(€)': 101.0, 'Discount (%)': 45.41, 'info': 'Miami Twin Pocket', 'Product Type': 'Overshirt'}
# {'brand': 'REISS', 'title': 'Babbington Check Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 92.0, 'Discount (%)': 52.82, 'info': 'Babbington Check', 'Product Type': 'Trousers'}
# {'brand': 'REISS', 'title': 'Primo Colour Block Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 78.0, 'Discount (%)': 44.29, 'info': 'Primo Colour Block Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Tate Garment Dye Oversized T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 29.0, 'Sales Price(€)': 29.0, 'Discount (%)': 0.0, 'info': 'Tate Garment Dye Oversized', 'Product Type': 'T-Shirt'}
# {'brand': 'REISS', 'title': 'Caprio Jersey Twill Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 64.0, 'Discount (%)': 54.29, 'info': 'Caprio Jersey Twill', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Oxford T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 52.0, 'Sales Price(€)': 36.0, 'Discount (%)': 30.77, 'info': 'Oxford', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Contrasting Floral Printed Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 165.0, 'Sales Price(€)': 82.5, 'Discount (%)': 50.0, 'info': 'Contrasting Floral Printed', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Short-Sleeve Striped T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 39.0, 'Sales Price(€)': 27.0, 'Discount (%)': 30.77, 'info': 'Short-Sleeve Striped', 'Product Type': 'T-Shirt'}
# {'brand': 'TED BAKER', 'title': 'Newton Dotted Slim Fit Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 66.0, 'Discount (%)': 30.53, 'info': 'Newton Dotted Slim Fit', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Irvine Slim Fit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 87.0, 'Discount (%)': 30.4, 'info': 'Irvine Slim Fit', 'Product Type': 'Trousers'}
# {'brand': 'TED BAKER', 'title': 'Almur Brushed Twill Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 78.0, 'Discount (%)': 40.0, 'info': 'Almur Brushed Twill', 'Product Type': 'Overshirt'}
# {'brand': 'TED BAKER', 'title': 'Coram Jacquard Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 100.0, 'Sales Price(€)': 50.0, 'Discount (%)': 50.0, 'info': 'Coram Jacquard Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Pebal Leyden Straight Fit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 78.0, 'Discount (%)': 40.0, 'info': 'Pebal Leyden Straight Fit', 'Product Type': 'Trousers'}
# {'brand': 'THE KOOPLES', 'title': 'Leopard Patch T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 57.0, 'Discount (%)': 40.0, 'info': 'Leopard Patch', 'Product Type': 'T-Shirt'}
# {'brand': 'TED BAKER', 'title': 'Heddonj Single Breasted Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 355.0, 'Sales Price(€)': 177.0, 'Discount (%)': 50.14, 'info': 'Heddonj Single Breasted', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Arid Drop Shoulder Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 62.0, 'Discount (%)': 52.31, 'info': 'Arid Drop Shoulder', 'Product Type': 'Overshirt'}
# {'brand': 'TED BAKER', 'title': 'Gallan Flannel Bomber Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 320.0, 'Sales Price(€)': 128.0, 'Discount (%)': 60.0, 'info': 'Gallan Flannel Bomber', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Blackhall Merino Wool Zip Neck Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 64.0, 'Discount (%)': 54.29, 'info': 'Blackhall Merino Wool Zip Neck', 'Product Type': 'Sweater'}
# {'brand': 'REISS', 'title': 'Tate Garment Dye Oversized T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 70.0, 'Sales Price(€)': 29.0, 'Discount (%)': 58.57, 'info': 'Tate Garment Dye Oversized', 'Product Type': 'T-Shirt'}
# {'brand': 'TED BAKER', 'title': 'Leyden Fit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 130.0, 'Sales Price(€)': 52.0, 'Discount (%)': 60.0, 'info': 'Leyden Fit', 'Product Type': 'Trousers'}
# {'brand': 'REISS', 'title': 'Caprio Jersey Twill Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 64.0, 'Discount (%)': 54.29, 'info': 'Caprio Jersey Twill', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Brookes Stitch Interest Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 140.0, 'Sales Price(€)': 64.0, 'Discount (%)': 54.29, 'info': 'Brookes Stitch Interest', 'Product Type': 'Sweater'}
# {'brand': 'THE KOOPLES', 'title': 'Straight Leg Jeans', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 165.0, 'Sales Price(€)': 82.5, 'Discount (%)': 50.0, 'info': 'Straight Leg', 'Product Type': 'Jeans'}
# {'brand': 'TED BAKER', 'title': 'Latima Jersey Joggers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 110.0, 'Sales Price(€)': 55.0, 'Discount (%)': 50.0, 'info': 'Latima Jersey', 'Product Type': 'Joggers'}
# {'brand': 'TED BAKER', 'title': 'Short Sleeve Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 59.0, 'Discount (%)': 30.59, 'info': 'Short Sleeve Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Pocket T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 59.0, 'Sales Price(€)': 41.0, 'Discount (%)': 30.51, 'info': 'Pocket', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Long-Sleeve Single-Breasted Suit Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 445.0, 'Sales Price(€)': 222.5, 'Discount (%)': 50.0, 'info': 'Long-Sleeve Single-Breasted Suit', 'Product Type': 'Jacket'}
# {'brand': 'THE KOOPLES', 'title': 'Flower Skull Patch T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 66.5, 'Discount (%)': 30.0, 'info': 'Flower Skull Patch', 'Product Type': 'T-Shirt'}
# {'brand': 'TED BAKER', 'title': 'Cromts Wool Check Suit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 180.0, 'Sales Price(€)': 126.0, 'Discount (%)': 30.0, 'info': 'Cromts Wool Check Suit', 'Product Type': 'Trousers'}
# {'brand': 'REISS', 'title': 'Jackson Blouson Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 385.0, 'Sales Price(€)': 172.0, 'Discount (%)': 55.32, 'info': 'Jackson Blouson', 'Product Type': 'Jacket'}
# {'brand': 'THE KOOPLES', 'title': 'Printed T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 57.0, 'Discount (%)': 40.0, 'info': 'Printed', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Denim Button Overshirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 235.0, 'Sales Price(€)': 117.5, 'Discount (%)': 50.0, 'info': 'Denim Button', 'Product Type': 'Overshirt'}
# {'brand': 'THE KOOPLES', 'title': 'Leopard Screenprint T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 135.0, 'Sales Price(€)': 67.5, 'Discount (%)': 50.0, 'info': 'Leopard Screenprint', 'Product Type': 'T-Shirt'}
# {'brand': 'REISS', 'title': 'Moat Funnel Neck Overcoat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 470.0, 'Sales Price(€)': 257.0, 'Discount (%)': 45.32, 'info': 'Moat Funnel Neck', 'Product Type': 'Overcoat'}
# {'brand': 'REISS', 'title': 'Skye Mid Length Puffer Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 322.0, 'Sales Price(€)': 322.0, 'Discount (%)': 0.0, 'info': 'Skye Mid Length Puffer', 'Product Type': 'Jacket'}
# {'brand': 'REISS', 'title': 'Parks Merino Wool Crew Neck Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 67.0, 'Sales Price(€)': 67.0, 'Discount (%)': 0.0, 'info': 'Parks Merino Wool Crew Neck', 'Product Type': 'Sweater'}
# {'brand': 'REISS', 'title': 'Babbington Single Breasted Check Blazer', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 425.0, 'Sales Price(€)': 256.0, 'Discount (%)': 39.76, 'info': 'Babbington Single Breasted Check', 'Product Type': 'Blazer'}
# {'brand': 'TED BAKER', 'title': 'Roymile Shadow Check Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 85.0, 'Sales Price(€)': 42.0, 'Discount (%)': 50.59, 'info': 'Roymile Shadow Check Polo', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Gaulby Contrast Stitch Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 68.0, 'Discount (%)': 60.0, 'info': 'Gaulby Contrast Stitch', 'Product Type': 'Trousers'}
# {'brand': 'TED BAKER', 'title': 'Hendon Long Sleeve Hoodie', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 62.0, 'Discount (%)': 50.4, 'info': 'Hendon Long Sleeve', 'Product Type': 'Hoodie'}
# {'brand': 'TED BAKER', 'title': 'Sorelss Textured Spot Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 66.0, 'Discount (%)': 30.53, 'info': 'Sorelss Textured Spot', 'Product Type': 'Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Wool Suit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 235.0, 'Sales Price(€)': 117.5, 'Discount (%)': 50.0, 'info': 'Wool Suit', 'Product Type': 'Trousers'}
# {'brand': 'THE KOOPLES', 'title': 'Two-Tone Embroidered Satin Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 465.0, 'Sales Price(€)': 232.5, 'Discount (%)': 50.0, 'info': 'Two-Tone Embroidered Satin', 'Product Type': 'Jacket'}
# {'brand': 'THE KOOPLES', 'title': 'Embroidered Tiger Quilted Bomber Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 445.0, 'Sales Price(€)': 222.5, 'Discount (%)': 50.0, 'info': 'Embroidered Tiger Quilted Bomber', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Maroc Jacquard Zip Polo Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 100.0, 'Sales Price(€)': 50.0, 'Discount (%)': 50.0, 'info': 'Maroc Jacquard Zip Polo', 'Product Type': 'Shirt'}
# {'brand': 'REISS', 'title': 'Vienna Wool Button Through Jacket', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 395.0, 'Sales Price(€)': 184.0, 'Discount (%)': 53.42, 'info': 'Vienna Wool Button Through', 'Product Type': 'Jacket'}
# {'brand': 'TED BAKER', 'title': 'Kensey Marled Wool Belted Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 117.0, 'Discount (%)': 40.0, 'info': 'Kensey Marled Wool Belted', 'Product Type': 'Trousers'}
# {'brand': 'TED BAKER', 'title': 'Canvee Harrington Over Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 170.0, 'Sales Price(€)': 65.0, 'Discount (%)': 61.76, 'info': 'Canvee Harrington Over', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Aclaret Slim Fit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 78.0, 'Discount (%)': 60.0, 'info': 'Aclaret Slim Fit', 'Product Type': 'Trousers'}
# {'brand': 'REISS', 'title': 'Root Herringbone Raglan Overcoat', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 525.0, 'Sales Price(€)': 256.0, 'Discount (%)': 51.24, 'info': 'Root Herringbone Raglan', 'Product Type': 'Overcoat'}
# {'brand': 'REISS', 'title': 'Matthew Cable Knit Sweater', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 64.0, 'Sales Price(€)': 64.0, 'Discount (%)': 0.0, 'info': 'Matthew Cable Knit', 'Product Type': 'Sweater'}
# {'brand': 'REISS', 'title': 'Gustav Oversized T-Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 95.0, 'Sales Price(€)': 41.0, 'Discount (%)': 56.84, 'info': 'Gustav Oversized', 'Product Type': 'T-Shirt'}
# {'brand': 'THE KOOPLES', 'title': 'Denim Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 155.0, 'Sales Price(€)': 93.0, 'Discount (%)': 40.0, 'info': 'Denim', 'Product Type': 'Shirt'}
# {'brand': 'TED BAKER', 'title': 'Edro Long Gingham Polo', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 100.0, 'Sales Price(€)': 40.0, 'Discount (%)': 60.0, 'info': 'Edro Long Gingham', 'Product Type': 'Polo'}
# {'brand': 'TED BAKER', 'title': 'Hendon Long Sleeve Hoodie', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 125.0, 'Sales Price(€)': 62.0, 'Discount (%)': 50.4, 'info': 'Hendon Long Sleeve', 'Product Type': 'Hoodie'}
# {'brand': 'THE KOOPLES', 'title': 'Wool Suit Trousers', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 235.0, 'Sales Price(€)': 117.5, 'Discount (%)': 50.0, 'info': 'Wool Suit', 'Product Type': 'Trousers'}
# {'brand': 'THE KOOPLES', 'title': 'Skull Print Tank Top', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 90.0, 'Sales Price(€)': 45.0, 'Discount (%)': 50.0, 'info': 'Skull Print Tank', 'Product Type': 'Top'}
# {'brand': 'THE KOOPLES', 'title': 'Striped Denim Shirt', 'collection': "Men's clothing", 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 195.0, 'Sales Price(€)': 97.5, 'Discount (%)': 50.0, 'info': 'Striped Denim', 'Product Type': 'Shirt'}
# ...
# {'brand': 'SONY', 'title': 'Sweatproof Loop Hang Earphones', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 29.95, 'Sales Price(€)': 19.95, 'Discount (%)': 33.39, 'info': 'Sweatproof Loop Hang', 'Product Type': 'Earphones'}
# {'brand': 'SONOS', 'title': 'Play:1 Wireless Player Black\xa0', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 799.95, 'Sales Price(€)': 599.95, 'Discount (%)': 25.0, 'info': 'Play:1 Wireless Player', 'Product Type': 'Black\xa0'}
# {'brand': 'SONY', 'title': 'Extra Bass In-Ear Headphones', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 34.95, 'Sales Price(€)': 31.5, 'Discount (%)': 9.87, 'info': 'Extra Bass In-Ear', 'Product Type': 'Headphones'}
# {'brand': 'LOMOGRAPHY', 'title': 'Fisheye No. 2 Camera', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 59.0, 'Sales Price(€)': 29.5, 'Discount (%)': 50.0, 'info': 'Fisheye No. 2', 'Product Type': 'Camera'}
# {'brand': 'FITBIT', 'title': 'Versa 4 Black/Graphite Smart Watch', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 229.95, 'Sales Price(€)': 199.95, 'Discount (%)': 13.05, 'info': 'Versa 4 Black/Graphite Smart', 'Product Type': 'Watch'}
# {'brand': 'LOMOGRAPHY', 'title': 'Diana Mini Camera & Flash Package', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 99.0, 'Sales Price(€)': 49.5, 'Discount (%)': 50.0, 'info': 'Diana Mini Camera & Flash', 'Product Type': 'Package'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Polaroid Go', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 119.95, 'Sales Price(€)': 99.95, 'Discount (%)': 16.67, 'info': 'Polaroid', 'Product Type': 'Go'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Now+', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 149.95, 'Sales Price(€)': 119.95, 'Discount (%)': 20.01, 'info': 'Now+', 'Product Type': None}
# {'brand': 'ITSKINS', 'title': 'Spectrum Clear Case For Oppo A16S/A54/A74', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 4.95, 'Sales Price(€)': 1.95, 'Discount (%)': 60.61, 'info': 'Spectrum Clear Case For Oppo', 'Product Type': 'A16S/A54/A74'}
# {'brand': 'EXPERT', 'title': 'Trust 20000mah USB-C powerbank', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 59.95, 'Sales Price(€)': 49.95, 'Discount (%)': 16.68, 'info': 'Trust 20000mah USB-C', 'Product Type': 'powerbank'}
# {'brand': 'PETCUBE', 'title': 'Petcube Bites 2 Lite Smart FHD Pet Camera', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 159.95, 'Sales Price(€)': 129.95, 'Discount (%)': 18.76, 'info': 'Petcube Bites 2 Lite Smart FHD Pet', 'Product Type': 'Camera'}
# {'brand': 'LOMOGRAPHY', 'title': 'Simple Use Film Camera Colour Negative 400', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 70.0, 'Sales Price(€)': 35.0, 'Discount (%)': 50.0, 'info': 'Simple Use Film Camera Colour Negative', 'Product Type': '400'}
# {'brand': 'NOMAD', 'title': 'Rugged Leather iPhone 11 6.5 Case', 'collection': 'Technology', 'Tag': 'EXTRA 10% OFF AT CHECKOUT', 'Standard Price(€)': 34.95, 'Sales Price(€)': 24.95, 'Discount (%)': 28.61, 'info': 'Rugged Leather iPhone 11 6.5', 'Product Type': 'Case'}
# {'brand': 'MOPHIE', 'title': 'Messenger Folio 2 Keyboard Case For 10.2 Inch To 10.5 Inch iPads', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 59.99, 'Sales Price(€)': 49.95, 'Discount (%)': 16.74, 'info': 'Messenger Folio 2 Keyboard Case For 10.2 Inch To 10.5 Inch', 'Product Type': 'iPads'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Go Film Double Pack', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 25.0, 'Sales Price(€)': 20.0, 'Discount (%)': 20.0, 'info': 'Go Film Double', 'Product Type': 'Pack'}
# {'brand': 'DBRAMANTE1928', 'title': 'New York iPhone 11 Pro Cover', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 15.0, 'Sales Price(€)': 5.0, 'Discount (%)': 66.67, 'info': 'New York iPhone 11 Pro', 'Product Type': 'Cover'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Color Film For 600', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 25.0, 'Sales Price(€)': 20.0, 'Discount (%)': 20.0, 'info': 'Color Film For', 'Product Type': '600'}
# {'brand': 'NOMAD', 'title': 'Sport Strap 40mm/38mm S/M Black FKM V2', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 49.95, 'Sales Price(€)': 29.95, 'Discount (%)': 40.04, 'info': 'Sport Strap 40mm/38mm S/M Black FKM', 'Product Type': 'V2'}
# {'brand': 'DBRAMANTE', 'title': 'iPad 10.2 (7th-9th Gen) Inch Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 59.95, 'Sales Price(€)': 44.95, 'Discount (%)': 25.02, 'info': 'iPad 10.2 (7th-9th Gen) Inch', 'Product Type': 'Case'}
# {'brand': 'TCL', 'title': 'Tab 10 Max 10.3 Inch 64Gb Tablet WiFi', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 249.95, 'Sales Price(€)': 199.95, 'Discount (%)': 20.0, 'info': 'Tab 10 Max 10.3 Inch 64Gb Tablet', 'Product Type': 'WiFi'}
# {'brand': 'SAMSUNG', 'title': 'Galaxy Watch 3 41mm', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 399.95, 'Sales Price(€)': 199.95, 'Discount (%)': 50.01, 'info': 'Galaxy Watch 3', 'Product Type': '41mm'}
# {'brand': 'DBRAMANTE', 'title': 'Grenen iPhone 12/12 Pro Black Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 69.99, 'Sales Price(€)': 10.95, 'Discount (%)': 84.35, 'info': 'Grenen iPhone 12/12 Pro Black', 'Product Type': 'Case'}
# {'brand': 'MOJIPOWER', 'title': 'Poison Airpods Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 15.0, 'Sales Price(€)': 8.95, 'Discount (%)': 40.33, 'info': 'Poison Airpods', 'Product Type': 'Case'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Polaroid Now+', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 149.95, 'Sales Price(€)': 119.95, 'Discount (%)': 20.01, 'info': 'Polaroid', 'Product Type': 'Now+'}
# {'brand': 'FITBIT', 'title': 'Versa 4 Pink Sand/Copper Rose Smart Watch', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 229.95, 'Sales Price(€)': 199.95, 'Discount (%)': 13.05, 'info': 'Versa 4 Pink Sand/Copper Rose Smart', 'Product Type': 'Watch'}
# {'brand': 'ZAGG', 'title': '4 In 1 Wireless Charging Mat', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 159.95, 'Sales Price(€)': 119.95, 'Discount (%)': 25.01, 'info': '4 In 1 Wireless Charging', 'Product Type': 'Mat'}
# {'brand': 'TP-LINK', 'title': 'Tapo Pan & Tilt 360 Home Security WiFi Camera', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 49.95, 'Sales Price(€)': 39.95, 'Discount (%)': 20.02, 'info': 'Tapo Pan & Tilt 360 Home Security WiFi', 'Product Type': 'Camera'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Go', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 119.95, 'Sales Price(€)': 99.95, 'Discount (%)': 16.67, 'info': 'Go', 'Product Type': None}
# {'brand': 'SAMSUNG', 'title': 'Galaxy Watch 5 44mm Sapphire', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 339.95, 'Sales Price(€)': 289.95, 'Discount (%)': 14.71, 'info': 'Galaxy Watch 5 44mm', 'Product Type': 'Sapphire'}
# {'brand': 'DBRAMANTE', 'title': 'Iceland iPhone 13 Pro Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 19.95, 'Sales Price(€)': 17.95, 'Discount (%)': 10.03, 'info': 'Iceland iPhone 13 Pro', 'Product Type': 'Case'}
# {'brand': 'TP-LINK', 'title': 'Wireless Dual Band 4G LTE Router', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 129.95, 'Sales Price(€)': 119.95, 'Discount (%)': 7.7, 'info': 'Wireless Dual Band 4G LTE', 'Product Type': 'Router'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Color Film for i-Type', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 25.0, 'Sales Price(€)': 20.0, 'Discount (%)': 20.0, 'info': 'Color Film for', 'Product Type': 'i-Type'}
# {'brand': 'SAMSUNG', 'title': 'Tab A8 - Book Cover', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 54.9, 'Sales Price(€)': 39.95, 'Discount (%)': 27.23, 'info': 'Tab A8 - Book', 'Product Type': 'Cover'}
# {'brand': 'ZAGG', 'title': 'Gear4 Havana Apple Kirk Iphone 14 Max FG', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 19.95, 'Sales Price(€)': 15.95, 'Discount (%)': 20.05, 'info': 'Gear4 Havana Apple Kirk Iphone 14 Max', 'Product Type': 'FG'}
# {'brand': 'DBRAMANTE1928', 'title': 'New York iPhone 11 Pro Cover', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 15.0, 'Sales Price(€)': 9.95, 'Discount (%)': 33.67, 'info': 'New York iPhone 11 Pro', 'Product Type': 'Cover'}
# {'brand': 'DBRAMANTE1928', 'title': 'Lynge iPhone 11 Pro Max Cover', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 19.95, 'Sales Price(€)': 9.95, 'Discount (%)': 50.13, 'info': 'Lynge iPhone 11 Pro Max', 'Product Type': 'Cover'}
# {'brand': 'HARMAN KARDON', 'title': 'Citation Bar', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 899.95, 'Sales Price(€)': 749.95, 'Discount (%)': 16.67, 'info': 'Citation', 'Product Type': 'Bar'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'B&W Film For I-Type', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 25.0, 'Sales Price(€)': 20.0, 'Discount (%)': 20.0, 'info': 'B&W Film For', 'Product Type': 'I-Type'}
# {'brand': 'DBRAMANTE', 'title': 'New York XIMAX BLACK Wallet Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 49.95, 'Sales Price(€)': 20.0, 'Discount (%)': 59.96, 'info': 'New York XIMAX BLACK Wallet', 'Product Type': 'Case'}
# {'brand': 'NOMAD', 'title': 'Rugged Folio - Black Leather iPhone 11 Pro Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 69.95, 'Sales Price(€)': 4.95, 'Discount (%)': 92.92, 'info': 'Rugged Folio - Black Leather iPhone 11 Pro', 'Product Type': 'Case'}
# {'brand': 'SAMSUNG', 'title': 'Galaxy Watch 5 45mm', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 479.95, 'Sales Price(€)': 389.95, 'Discount (%)': 18.75, 'info': 'Galaxy Watch 5', 'Product Type': '45mm'}
# {'brand': 'JABRA', 'title': 'Elite 45H Headphones', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 99.95, 'Sales Price(€)': 89.95, 'Discount (%)': 10.01, 'info': 'Elite 45H', 'Product Type': 'Headphones'}
# {'brand': 'RAZER', 'title': 'BlackWidow V3 (Green Switch) - UK Layout', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 149.95, 'Sales Price(€)': 129.95, 'Discount (%)': 13.34, 'info': 'BlackWidow V3 (Green Switch) - UK', 'Product Type': 'Layout'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Polaroid Now', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 129.95, 'Sales Price(€)': 99.95, 'Discount (%)': 23.09, 'info': 'Polaroid', 'Product Type': 'Now'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Now Black & White', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 129.95, 'Sales Price(€)': 99.95, 'Discount (%)': 23.09, 'info': 'Now Black &', 'Product Type': 'White'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Polaroid Now', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 129.95, 'Sales Price(€)': 99.95, 'Discount (%)': 23.09, 'info': 'Polaroid', 'Product Type': 'Now'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Polaroid Now', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 129.95, 'Sales Price(€)': 99.95, 'Discount (%)': 23.09, 'info': 'Polaroid', 'Product Type': 'Now'}
# {'brand': 'POLAROID ORIGINALS', 'title': 'Go Film Double Pack Black Frame Edition', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 25.0, 'Sales Price(€)': 20.0, 'Discount (%)': 20.0, 'info': 'Go Film Double Pack Black Frame', 'Product Type': 'Edition'}
# {'brand': 'ZAGG', 'title': 'InvisibleShield Ultra Clear+ S22 Screen Clear', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 24.99, 'Sales Price(€)': 19.95, 'Discount (%)': 20.17, 'info': 'InvisibleShield Ultra Clear+ S22 Screen', 'Product Type': 'Clear'}
# {'brand': 'DBRAMANTE', 'title': 'Copenhagen 2, iPad Air/Pro 10.5 Inch - Protective Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 39.95, 'Sales Price(€)': 24.95, 'Discount (%)': 37.55, 'info': 'Copenhagen 2, iPad Air/Pro 10.5 Inch - Protective', 'Product Type': 'Case'}
# {'brand': 'PANZERGLASS', 'title': 'Samsung Galaxy S22 Screen Protector', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 29.95, 'Sales Price(€)': 24.95, 'Discount (%)': 16.69, 'info': 'Samsung Galaxy S22 Screen', 'Product Type': 'Protector'}
# {'brand': 'DBRAMANTE', 'title': 'Iceland Pro Samsung Galaxy S22 Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 29.95, 'Sales Price(€)': 19.95, 'Discount (%)': 33.39, 'info': 'Iceland Pro Samsung Galaxy S22', 'Product Type': 'Case'}
# {'brand': 'DBRAMANTE', 'title': 'Greenland Samsung Galaxy S22 Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 24.95, 'Sales Price(€)': 15.95, 'Discount (%)': 36.07, 'info': 'Greenland Samsung Galaxy S22', 'Product Type': 'Case'}
# {'brand': 'DBRAMANTE', 'title': 'Iceland Pro Samsung Galaxy S22 Plus Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 19.95, 'Sales Price(€)': 15.95, 'Discount (%)': 20.05, 'info': 'Iceland Pro Samsung Galaxy S22 Plus', 'Product Type': 'Case'}
# {'brand': 'DBRAMANTE', 'title': 'Monaco iPhone 13 Pro Max Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 29.95, 'Sales Price(€)': 24.95, 'Discount (%)': 16.69, 'info': 'Monaco iPhone 13 Pro Max', 'Product Type': 'Case'}
# {'brand': 'PANZERGLASS', 'title': 'iPhone 13 Mini Screen Protector', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 29.95, 'Sales Price(€)': 19.95, 'Discount (%)': 33.39, 'info': 'iPhone 13 Mini Screen', 'Product Type': 'Protector'}
# {'brand': 'EPSON', 'title': 'WorkForce ES-50 A4 Mobile Scanner', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 139.95, 'Sales Price(€)': 119.95, 'Discount (%)': 14.29, 'info': 'WorkForce ES-50 A4 Mobile', 'Product Type': 'Scanner'}
# {'brand': 'EXPERT', 'title': '512GB 1.8 Inch External SSD USB 3.0', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 449.95, 'Sales Price(€)': 49.95, 'Discount (%)': 88.9, 'info': '512GB 1.8 Inch External SSD USB', 'Product Type': '3.0'}
# {'brand': 'DBRAMANTE', 'title': 'Milano iPhone 12/12 Pro 6.1 Inch 2-In-1 Case', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 39.95, 'Sales Price(€)': 19.95, 'Discount (%)': 50.06, 'info': 'Milano iPhone 12/12 Pro 6.1 Inch 2-In-1', 'Product Type': 'Case'}
# {'brand': 'TP-LINK', 'title': 'Tapo Outdoor Securtiy WiFi Camera', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 79.95, 'Sales Price(€)': 59.95, 'Discount (%)': 25.02, 'info': 'Tapo Outdoor Securtiy WiFi', 'Product Type': 'Camera'}
# {'brand': 'TP-LINK', 'title': 'Deco Whole-Home Wi-Fi 3 Pack', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 189.95, 'Sales Price(€)': 189.95, 'Discount (%)': 0.0, 'info': 'Deco Whole-Home Wi-Fi 3', 'Product Type': 'Pack'}
# {'brand': 'OTTERBOX', 'title': 'Lightning Cable 1 metre', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 24.95, 'Sales Price(€)': 19.95, 'Discount (%)': 20.04, 'info': 'Lightning Cable 1', 'Product Type': 'metre'}
# {'brand': 'SO SEVEN', 'title': 'Jaipur Leopard iPhone 11', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 39.99, 'Sales Price(€)': 18.99, 'Discount (%)': 52.51, 'info': 'Jaipur Leopard iPhone', 'Product Type': '11'}
# {'brand': 'KYGO', 'title': 'X by Kygo E7/1000 True Wireless Earphones', 'collection': 'Technology', 'Tag': 'SALE', 'Standard Price(€)': 149.95, 'Sales Price(€)': 99.95, 'Discount (%)': 33.34, 'info': 'X by Kygo E7/1000 True Wireless', 'Product Type': 'Earphones'}

# %%
#1 – What products are on sale?
result_list = final_data[final_data['Tag'] == "SALE"]
result_list['collection'].value_counts()
# Out:
# Women's Clothing    373
# Shoes               247
# Eye care            176
# Technology           85
# Bags                 54
# Name: collection, dtype: int64

# %%
#2 – Of the products on sale, which is the cheapest?
minimum_price = min(result_list['Sales Price(€)'])
result_list[result_list['Sales Price(€)'] == minimum_price]
# Out:
#       brand                                      title  collection   Tag  \
# 36  ITSKINS  Spectrum Clear Case For Oppo A16S/A54/A74  Technology  SALE
#
#     Standard Price(€)  Sales Price(€)  Discount (%)  \
# 36               4.95            1.95         60.61
#
#                             info  Product Type
# 36  Spectrum Clear Case For Oppo  A16S/A54/A74

# %%
#3 – Still thinking about products on sale, what is the best discount margin that we can observe?
max_discount = max(result_list['Discount (%)'])
print(max_discount)
result_list[result_list['Discount (%)'] == max_discount]
# Out:
# 92.92
#     brand                                            title  collection   Tag  \
# 71  NOMAD  Rugged Folio - Black Leather iPhone 11 Pro Case  Technology  SALE
#
#     Standard Price(€)  Sales Price(€)  Discount (%)  \
# 71              69.95            4.95         92.92
#
#                                           info Product Type
# 71  Rugged Folio - Black Leather iPhone 11 Pro         Case

# %%
#4 - How many products on sale does each brand have?
result_list.groupby(['brand']).size()
# Out:
# brand
# APPLE               5
# BA&SH             152
# BOTTEGA VENETA      4
# BURBERRY            4
# BVLGARI            15
#                  ...
# VERSACE             1
# VOGUE               3
# WHISTLES           47
# ZADIG&VOLTAIRE    134
# ZAGG                3
# Length: 63, dtype: int64

# %%
#5 – How many pants does each brand have?
pants = final_data[final_data["Product Type"] == "Trousers"].groupby("brand").size()
pants
# Out:
# brand
# BA&SH               9
# CLAUDIE PIERLOT    10
# FOREVER NEW         3
# HOBBS               2
# LK BENNETT          1
# MAJE               13
# PHASE EIGHT         7
# REISS              18
# SANDRO              7
# TED BAKER          40
# THE KOOPLES        13
# WHISTLES           10
# ZADIG&VOLTAIRE      6
# dtype: int64

# %%
#6 – How many shirts do we have in the whole dataset?
len(final_data[final_data['Product Type'] == "Shirt"])
# Out:
# 317

# %%
#7 – What is the most expensive item of each brand without the discount?
expensive = final_data.groupby("brand")["Standard Price(€)"].max()
expensive
# Out:
# brand
# ACNE STUDIOS         890.00
# ADIDAS               110.00
# ALAMEDA TURQUESA     119.00
# ALEXANDER MCQUEEN    780.00
# ALEXANDER WANG       620.00
#                       ...
# VOGUE                 99.00
# VUORI                110.00
# WHISTLES             429.00
# ZADIG&VOLTAIRE       995.00
# ZAGG                 159.95
# Name: Standard Price(€), Length: 114, dtype: float64

# %%
#8 - What is the cheapest item of each brand after discount ?
cheapest = final_data.groupby("brand")["Sales Price(€)"].min()
cheapest
# Out:
# brand
# ACNE STUDIOS         195.00
# ADIDAS                52.50
# ALAMEDA TURQUESA      79.00
# ALEXANDER MCQUEEN    169.00
# ALEXANDER WANG       245.00
#                       ...
# VOGUE                 50.00
# VUORI                 35.00
# WHISTLES              25.00
# ZADIG&VOLTAIRE        51.00
# ZAGG                  15.95
# Name: Sales Price(€), Length: 114, dtype: float64

# %%
#9 – Adding all the items of a brand, which is the most expensive brand?
exp_brand = final_data.groupby("brand")["Standard Price(€)"].max().idxmax()
exp_brand
# Out:
# 'DUNE LONDON'

# %%
#10 – What is the price of the most expensive Jacket of a particular brand in our brown thomas dataset?
suits = final_data[final_data["Product Type"] == "Jacket"].groupby("brand")["Sales Price(€)"].max()
suits
# Out:
# brand
# BA&SH              171.5
# CLAUDIE PIERLOT    207.5
# MAJE               277.5
# PHASE EIGHT        128.0
# REISS              360.0
# SANDRO             231.0
# TED BAKER          333.0
# THE KOOPLES        347.5
# WHISTLES           169.0
# ZADIG&VOLTAIRE     311.5
# Name: Sales Price(€), dtype: float64

# %%
#11 – Which collection has the most products?
max_collection = final_data.groupby('collection').size().idxmax()
max_collection
# Out:
# "Women's Clothing"

# %%
#12 - What are items a customer can purchase for a budget of 150 - 200?
filtered_values = final_data.loc[(final_data['Sales Price(€)'] >= 10) & (final_data['Sales Price(€)']<50)]
filtered_values
# Out:
#           brand                                         title      collection  \
# 14    TED BAKER                           Caplet Oxford Shirt  Men's clothing
# 29    TED BAKER      Tinot Abstract Watercolour Print T-Shirt  Men's clothing
# 51    TED BAKER             Taigaa Stripe Panelled Polo Shirt  Men's clothing
# 61    TED BAKER                       Fonik Long Sleeve Shirt  Men's clothing
# 74    TED BAKER             Taigaa Stripe Panelled Polo Shirt  Men's clothing
# ..          ...                                           ...             ...
# 89  PANZERGLASS               iPhone 13 Mini Screen Protector      Technology
# 91       EXPERT           512GB 1.8 Inch External SSD USB 3.0      Technology
# 92    DBRAMANTE  Milano iPhone 12/12 Pro 6.1 Inch 2-In-1 Case      Technology
# 95     OTTERBOX                       Lightning Cable 1 metre      Technology
# 96     SO SEVEN                      Jaipur Leopard iPhone 11      Technology
#
#                           Tag  Standard Price(€)  Sales Price(€)  \
# 14  EXTRA 10% OFF AT CHECKOUT              99.00           49.00
# 29  EXTRA 10% OFF AT CHECKOUT              59.00           35.00
# 51  EXTRA 10% OFF AT CHECKOUT              85.00           42.00
# 61  EXTRA 10% OFF AT CHECKOUT              99.00           49.00
# 74  EXTRA 10% OFF AT CHECKOUT              85.00           42.00
# ..                        ...                ...             ...
# 89                       SALE              29.95           19.95
# 91                       SALE             449.95           49.95
# 92                       SALE              39.95           19.95
# 95                       SALE              24.95           19.95
# 96                       SALE              39.99           18.99
#
#     Discount (%)                                     info Product Type
# 14         50.51                            Caplet Oxford        Shirt
# 29         40.68         Tinot Abstract Watercolour Print      T-Shirt
# 51         50.59              Taigaa Stripe Panelled Polo        Shirt
# 61         50.51                        Fonik Long Sleeve        Shirt
# 74         50.59              Taigaa Stripe Panelled Polo        Shirt
# ..           ...                                      ...          ...
# 89         33.39                    iPhone 13 Mini Screen    Protector
# 91         88.90          512GB 1.8 Inch External SSD USB          3.0
# 92         50.06  Milano iPhone 12/12 Pro 6.1 Inch 2-In-1         Case
# 95         20.04                        Lightning Cable 1        metre
# 96         52.51                    Jaipur Leopard iPhone           11
#
# [333 rows x 9 columns]

# %%
#13 - If a customer wants to create an outfit, what is the maximum savings they can get after buying item from each category?
a = final_data[final_data["collection"] == "Women's Clothing"]
filtered1 = a.loc[a['Product Type'] == "Top"] 
filtered2 = a.loc[a['Product Type'] == "Trouser"]
filtered3 = a.loc[a['Product Type'] == "Blazer"]
discount1 = max(filtered1['Discount (%)'])
discount2 = max(filtered2['Discount (%)'])
discount3 = max(filtered3['Discount (%)'])
total_discount_outfit = (discount1 + discount2 + discount3) / 3
total_discount_outfit
# Out:
# 57.94

# %%
# 14 Which brand sells the most Eye Care products?
best_eyecare_brand = final_data[final_data['collection'] == "Eye care"].groupby('brand').size().idxmax()
total_items = final_data[final_data['collection'] == "Eye care"].groupby('brand').size().max()
print(best_eyecare_brand)
print(total_items)
# Out:
# RAY-BAN
# 42

# %%
#15 What are the different theme tags for the products available on the website and state their respective counts?
final_data['Tag'].value_counts()
# Out:
# EXTRA 10% OFF AT CHECKOUT    2762
# SALE                          935
# Vegan                           2
# NEW DESIGNER                    2
# Low Impact Materials            1
# Low Impact Production           1
# Name: Tag, dtype: int64

# %%
#16 Which are the top-5 brands with big discounts on the products?
final_data.sort_values('Discount (%)',ascending = False)['brand'].head(5)
# Out:
# 256     DUNE LONDON
# 1479    PHASE EIGHT
# 71            NOMAD
# 91           EXPERT
# 22           SPHERO
# Name: brand, dtype: object
